# %%
#Kato Sharif Achen
#M24B13/046

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib as mtb
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#giving the student variable and reading the excel data
student_dfs=pd.read_csv("Students.csv",delimiter=';')

# %%
#inspecting the variable data
student_dfs.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
#probability of the students to graduate
graduate_probability=student_dfs['Target'].value_counts(normalize=True).get('Graduate',0)
graduate_probability
# Out:
# np.float64(0.4993218806509946)

# %%
#probability of students to dropout of with material
dropout_with_marital_status_1=student_dfs[(student_dfs['Target']== 'Dropout') & (student_dfs['Marital status']==1)]
dropouts_proability=len(dropout_with_marital_status_1)/len(student_dfs)
dropouts_proability
# Out:
# 0.26763110307414106

# %%
#The relation between mother and targetno C
relationsip=pd.crosstab(student_dfs['Mother\'s qualification'],student_dfs['Target'],normalize='columns')
relationsip
# Out:
# Target                   Dropout  Enrolled  Graduate
# Mother's qualification
# 1                       0.211119  0.256927  0.255772
# 2                       0.014075  0.028967  0.018108
# 3                       0.097818  0.127204  0.089633
# 4                       0.005630  0.018892  0.011770
# 5                       0.005630  0.006297  0.003622
# 6                       0.002111  0.000000  0.000453
# 9                       0.003519  0.000000  0.001358
# 10                      0.001407  0.000000  0.000453
# 11                      0.001407  0.000000  0.000453
# 12                      0.015482  0.003778  0.007696
# 14                      0.000704  0.000000  0.000453
# 18                      0.000704  0.000000  0.000000
# 19                      0.190711  0.221662  0.229063
# 22                      0.000000  0.000000  0.000453
# 26                      0.000000  0.000000  0.000453
# 27                      0.000704  0.000000  0.000000
# ...

# %%
#students description
student_dfs.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
#ploting the graph
student_dfs.hist(column="Mother's qualification",by="Target",figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'Dropout'}>,
#         <Axes: title={'center': 'Enrolled'}>],
#        [<Axes: title={'center': 'Graduate'}>, <Axes: >]], dtype=object)
